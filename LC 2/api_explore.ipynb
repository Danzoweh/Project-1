# %%
import pandas as pd 

df = pd.read_csv("C:\Program Files\Hacktiv8\Phase 0\LC 2\horse_clean.csv")

horse = pd.read_csv("horse_clean.csv")

df
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9412\1717619899.py:3: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("C:\Program Files\Hacktiv8\Phase 0\LC 2\horse_clean.csv")
#    Unnamed: 0 surgery    age  hospital_number  rectal_temp  pulse  \
# 0          10     yes  adult           528548         38.1   66.0
# 1          54      no  adult           529461         40.3  114.0
# 2          64     yes  adult           529667         39.0   64.0
# 3          91      no  adult           529461         40.3  114.0
# 4         104     yes  adult           527563         37.8   52.0
# 5         188     yes  adult          5299603         38.3   60.0
#
#    respiratory_rate temp_of_extremities peripheral_pulse mucous_membrane  ...  \
# 0              12.0                cool          reduced      bright_red  ...
# 1              36.0                cool          reduced     normal_pink  ...
# 2              36.0                cool           normal   pale_cyanotic  ...
# 3              36.0                cool          reduced     normal_pink  ...
# 4              24.0              normal          reduced       pale_pink  ...
# 5              16.0                cool           normal     normal_pink  ...
#
#   packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0               44.0           6.0            cloudy            3.6
# 1               57.0           8.1     serosanguious            4.5
# 2               44.0           7.5     serosanguious            5.0
# 3               57.0           8.1     serosanguious            4.5
# 4               48.0           6.6             clear            3.7
# 5               30.0           6.0             clear            3.0
#
#       outcome surgical_lesion  lesion_1 lesion_2 lesion_3  cp_data
# 0       lived             yes      2124        0        0      yes
# 1  euthanized             yes      7400        0        0      yes
# 2       lived             yes      2113        0        0      yes
# 3        died             yes      3205        0        0      yes
# 4        died             yes      5400        0        0       no
# 5       lived             yes     31110        0        0       no
#
# [6 rows x 29 columns]
