# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()
print('Authenticated')

project_id = "kisilc3"

client = bigquery.Client(project=project_id)
# Out:
# Authenticated

# %%
df = client.query('''
SELECT *
FROM `bigquery-public-data.properati_properties_ar.properties_rent_201501`
''').to_dataframe()

df
# Out:
#                                             id  created_on operation  \
# 0     c6bd9655ab214262f35dc01991e93257ef27a80e  2014-10-14      rent
# 1     271e03d0640ca794bd0c96185cbe6565e5cbb532  2015-01-27      rent
# 2     3c270a1a138cdc8caec56effb996e466ddf32b7d  2014-09-12      rent
# 3     41ef61845ba4e05528569a1890520abc28409862  2014-11-21      rent
# 4     565382b9fb48cebf10820a8010fa33ff1ffa195b  2014-12-02      rent
# ...                                        ...         ...       ...
# 3291  c68a7554dcd6ae34b7ceb2cde8f931db8b575e31  2014-12-22      rent
# 3292  c24f751acf9332ee53b954498566beee4d572718  2015-01-27      rent
# 3293  5c4fe3f1f17c5862902d7fcc52a9d599a4e1b3cc  2015-01-20      rent
# 3294  b154bc45c2968f553e02925865771d2319f28865  2015-01-24      rent
# 3295  1c25ca22734a2268fcea5eef00027f8d45077b41  2014-12-23      rent
#
#      property_type       place_name  \
# 0        apartment          Córdoba
# 1        apartment          Córdoba
# 2        apartment          Córdoba
# 3        apartment          Córdoba
# 4            house          Córdoba
# ...            ...              ...
# 3291         house  Valeria del Mar
# 3292         house  Valeria del Mar
# 3293     apartment  Valeria del Mar
# 3294         house  Valeria del Mar
# 3295         house  Valeria del Mar
#
#                                 place_with_parent_names country_name  \
# 0                                   |Argentina|Córdoba|    Argentina
# 1                                   |Argentina|Córdoba|    Argentina
# 2                                   |Argentina|Córdoba|    Argentina
# 3                                   |Argentina|Córdoba|    Argentina
# 4                                   |Argentina|Córdoba|    Argentina
# ...                                                 ...          ...
# 3291  |Argentina|Buenos Aires Costa Atlántica|Valeri...    Argentina
# 3292  |Argentina|Buenos Aires Costa Atlántica|Valeri...    Argentina
# 3293  |Argentina|Buenos Aires Costa Atlántica|Valeri...    Argentina
# 3294  |Argentina|Buenos Aires Costa Atlántica|Valeri...    Argentina
# 3295  |Argentina|Buenos Aires Costa Atlántica|Valeri...    Argentina
#
#                         state_name  geonames_id                  lat_lon  ...  \
# 0                          Córdoba      3860255  -31.4130559,-64.1635496  ...
# 1                          Córdoba      3860255  -32.2492552,-62.6383524  ...
# 2                          Córdoba      3860255   -31.4058291,-64.166296  ...
# 3                          Córdoba      3860255   -31.3866062,-64.216713  ...
# 4                          Córdoba      3860255  -31.4016324,-64.1678943  ...
# ...                            ...          ...                      ...  ...
# 3291  Buenos Aires Costa Atlántica      3427561  -37.1400261,-56.8920174  ...
# 3292  Buenos Aires Costa Atlántica      3427561  -37.1400261,-56.8920174  ...
# 3293  Buenos Aires Costa Atlántica      3427561  -37.1400261,-56.8920174  ...
# 3294  Buenos Aires Costa Atlántica      3427561  -37.1400261,-56.8920174  ...
# 3295  Buenos Aires Costa Atlántica      3427561  -37.1400261,-56.8920174  ...
#
#       surface_covered_in_m2  price_usd_per_m2  price_per_m2 floor  rooms  \
# 0                      <NA>               NaN           NaN  <NA>   <NA>
# 1                      <NA>               NaN           NaN  <NA>   <NA>
# 2                      <NA>               NaN           NaN  <NA>   <NA>
# 3                        28               NaN     66.071429  <NA>   <NA>
# 4                       400               NaN     18.750000  <NA>   <NA>
# ...                     ...               ...           ...   ...    ...
# 3291                   <NA>             3.318           NaN  <NA>      1
# 3292                   <NA>             3.318           NaN  <NA>      1
# 3293                   <NA>             3.318           NaN  <NA>      1
# 3294                   <NA>             3.318           NaN  <NA>      1
# 3295                   <NA>             3.318           NaN  <NA>      1
#
#       expenses                                      properati_url  \
# 0         <NA>  http://www.properati.com.ar/j1jl_alquiler_depa...
# 1         <NA>  http://www.properati.com.ar/kl57_alquiler_depa...
# 2         <NA>  http://www.properati.com.ar/ihr7_alquiler_depa...
# 3         <NA>  http://www.properati.com.ar/jru5_alquiler_depa...
# 4         <NA>  http://www.properati.com.ar/jx35_alquiler_casa...
# ...        ...                                                ...
# 3291      <NA>  http://www.properati.com.ar/k4ph_alquiler_casa...
# 3292      <NA>  http://www.properati.com.ar/kl3m_alquiler_casa...
# 3293      <NA>  http://www.properati.com.ar/kied_alquiler_depa...
# 3294      <NA>  http://www.properati.com.ar/kksu_alquiler_casa...
# 3295      <NA>  http://www.properati.com.ar/k5e6_alquiler_casa...
#
#                                             description  \
# 0     CODIGO:  ubicado en: Av. 24 de Septiembre 1500...
# 1     CODIGO: 928-AAA2 ubicado en: CONSTITUCION 515 ...
# 2     CODIGO:  ubicado en: ARMENIA 1500 -  Publicado...
# 3     CODIGO:  ubicado en: AV CARAFFA ESQUINA GATO Y...
# 4     CODIGO:  ubicado en: ROMA 1300 -  Publicado po...
# ...                                                 ...
# 3291  Para mas informacion en nuestra pagina Daniel ...
# 3292  Para mas informacion en nuestro portal danielb...
# 3293  Para mas informacion en nuestro portal danielb...
# 3294  Para mas informacion en nuestro portal danielb...
# 3295  Para mas opciones en nuestro Blog Daniel Brigg...
#
#                                                   title  \
# 0             1 dormitorio Av. 24 de Septiembre al 1500
# 1     HERMOSO DPTO 1 DORM., 1 CUADRA PLAZA CENTRAL, ...
# 2          ALQUILER- DEPARTAMENTO  1 DORM Bº PUEYRREDON
# 3     VILLA CABRERA - MONOAMBIENTE -  Av CARAFFA ALQ...
# 4       ALQUILER__Bº PUEYRREDON CASA 3 DORM.(roma 1300)
# ...                                                 ...
# 3291                                      Casa alquiler
# 3292                                      Casa alquiler
# 3293                             Departamentos alquiler
# 3294                                      Casa alquiler
# 3295                                      Casa alquiler
#
#                                         image_thumbnail
# 0     https://thumbs4.properati.com/4/EgZ85yu3sEnl75...
# 1     https://thumbs4.properati.com/5/fw7PzqiMtqJIi1...
# 2     https://thumbs4.properati.com/7/3hUY0xZYvBs9a0...
# 3     https://thumbs4.properati.com/9/_bLCgo7EEuQaUj...
# 4     https://thumbs4.properati.com/2/XpLMkJyw06Gjyd...
# ...                                                 ...
# 3291  https://thumbs4.properati.com/9/JyVrcVM4Iu8097...
# 3292  https://thumbs4.properati.com/9/WTTisYwdeIJpkp...
# 3293  https://thumbs4.properati.com/3/EefKJnxcpQhVXx...
# 3294  https://thumbs4.properati.com/8/KQQ3I7XLJrOAGz...
# 3295  https://thumbs4.properati.com/9/t8pY11tcJGHS9O...
#
# [3296 rows x 27 columns]

# %% [markdown]
# Maaf kak , saya mau ngulang fase saja
